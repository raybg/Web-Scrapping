# %%
import requests 
import urllib
from bs4 import BeautifulSoup as bs
import csv
from urllib.request import urlopen as uReq

# %%
#from urllib.request import urlopen, Request
#headers = {'User-Agent': 'Chrome/79.0.3945.130'}
#url = "https://www.programmableweb.com/category/tools/api"
#req = Request(url=url, headers=headers) 
#html = urlopen(req)

url = ("https://www.1mg.com/categories/fitness-supplements/vitamins-minerals/multivitamins-162")
uClient = uReq(url)
soup = bs(uClient.read(),"html.parser")
uClient.close()

print(soup)
# Out:
# <!DOCTYPE html>
# <!-- Chrome, Firefox OS, Opera and Vivaldi -->
# <meta content="#FFF3E3" name="theme-color"/>
# <!-- Windows Phone -->
# <meta content="#FFF3E3" name="msapplication-navbutton-color"/>
# <!-- iOS Safari -->
# <meta content="#FFF3E3" name="apple-mobile-web-app-status-bar-style"/>
# ...

# %%
containers = soup.findAll("div",{"class":"content-container"})
#containers = soup.findAll("div", {"class": "col-md-3 col-sm-4 col-xs-6 style__container___1TL2R"})

len(containers)
# Out:
# 0

# %%
#soup.title
#soup.a
#soup.p
#soup.div
#soup.body.span
# Out:
# <span class="styles__free-tag___3x08e">Free</span>

# %%
name=[]  # a list to store names
price=[] # a list to store the price
    
name = soup.findAll('div', attrs = {"class": "col-md-3 col-sm-4 col-xs-6 style__container___1TL2R"}) 
  
for row in name:
    print(row)
   


'''
name = {} 
    name['theme'] = row.h5.text 
    name['url'] = row.a['href'] 
    name['img'] = row.img['src'] 
    name['lines'] = row.h6.text 
    name['author'] = row.p.text 
    name.append(quote) 
  

   
'''
# Out:
# <div class="col-md-3 col-sm-4 col-xs-6 style__container___1TL2R"><div class="style__product-box___liepi" itemscope="" itemtype="https://schema.org/Product"><a class="style__product-link___UB_67" href="/otc/1mg-multivitamin-supreme-capsule-otc503409" target="_blank"><meta content="/otc/1mg-multivitamin-supreme-capsule-otc503409" itemprop="url"><meta content="https://res.cloudinary.com/du8msdgbj/images/w_150,h_150,c_fit,q_auto,f_auto/v1562675422/xezyuhm5jwhjcydrhgfw/1mg-multivitamin-supreme-capsule.png" itemprop="image"><div class="style__product-image___1F9l3"><div class=""></div></div><div class="style__timer-container___36B_j"><div class="SaleCounter__small-font___3Aoqw SaleCounter__deals-view___2uGIM"></div></div><div class="style__product-description___2XaG0"><div class="style__pro-title___2QwJy" itemprop="name">1mg Multivitamin Supreme Capsule</div><div class="style__pack-size___2JQG7">bottle of 60 capsules</div></div><div class="style__product-pricing___38PRR" itemprop="offers" 
# ...

# %%
filename = 'inspirational_quotes.csv'
headers = 'name,price'

f = open(out_filename, "w")
f.write(headers)

#print(bsobject.encode("utf-8"),file=f)
