# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import csv
import pandas as pd
from urllib.request import urlopen as uReq

# %%
url = 'https://www.91mobiles.com/mobile-price-list-in-india'

uClient = uReq(url)
page_html = uClient.read()

page_soup = bs(page_html,"html.parser")

# %%
chrome_path = r"C:\Users\BG\Downloads\chromedriver_win32\chromedriver.exe"
driver = webdriver.Chrome(chrome_path)

mobname=[] #List to store name of the mobile

driver.get(url)

# print the first 500 characters of the HTML

#print(r.text[0:500])

# %%
content = driver.page_source
soup = bs(content)

table = soup.findAll('div', attrs = {'class':'finder_snipet_wrap'})

#len(table)
#table[0:5]
#table [-1]

# %%
for a in table:
    mname=a.find('h3')
    price=a.find('span',attrs={'class':'price price_padding'})
    child=a.find('div',attrs={'class':'filter-grey-bar filter_gray_bar_margin'})
    for li in child.findAll('li'):
        print(mname.text,price.text,li.text)
# Out:
# Xiaomi Poco X2 Rs.15,999 Performance
#
#
#
#
#
#
#
#
#
#
#
# Octa core (2.2 GHz, Dual Core + 1.8 GHz, Hexa Core)Snapdragon 730G6 GB RAM
# Xiaomi Poco X2 Rs.15,999 Display
#
#
#
#
#
#
#
#
#
#
#
# 6.67 inches (16.94 cm)1080x2400 px, 395 PPIIPS LCD
# Xiaomi Poco X2 Rs.15,999 Camera
#
#
#
#
#
#
#
#
#
#
#
# 64 + 8 + 2 + 2 MP Quad Primary CamerasLED Flash20 MP + 2 MP Dual Front Cameras
# Xiaomi Poco X2 Rs.15,999 Battery
#
#
#
#
#
#
#
#
#
#
#
# 4500 mAhFast ChargingUSB Type-C port
# Realme C3 Rs.6,999 Performance
#
#
#
#
#
#
#
#
#
#
#
# Octa core (2 GHz, Dual Core + 1.7 GHz, Hexa Core)MediaTek Helio G703 GB RAM
# Realme C3 Rs.6,999 Display
#
#
#
#
#
#
#
#
#
#
#
# 6.5 inches (16.51 cm)720x1600 px, 270 PPIIPS LCD
# Realme C3 Rs.6,999 Camera
#
#
#
#
#
#
#
#
#
#
#
# 12 MP + 2 MP Dual Primary CamerasLED Flash5 MP Front Camera
# Realme C3 Rs.6,999 Battery
#
#
#
#
#
#
#
#
#
#
#
# 5000 mAhNon-Removable
# Samsung Galaxy A51 Rs.23,999 Performance
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
for a in table.find('div',attrs = {'class':'finder_snipet_wrap'}):
    mname=('div',attrs = {'class':'filter-main'})

    print(mname.text)

#mobname.append(mname)
# Out:
#   File "<ipython-input-60-19cb1e39063c>", line 2
#     mname=('div',attrs = {'class':'filter-main'})
#                        ^
# SyntaxError: invalid syntax

# %%
#Extract user ids from each user on a page
    userid_element = driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[2]/div[1]/span[1]/a[2]')[0]
    userid = userid_element.text

# %%
mname = driver.find_elements_by_xpath('''//*[@id="finderResults"]/div[4]/div[1]/div[2]/div[1]/div/span/h3/a''')
mobilename = mname.text
mobilename

# %%
df = pd.DataFrame({'Mobile Name':mobname}) 
df.to_csv('products.csv', index=False, encoding='utf-8')
